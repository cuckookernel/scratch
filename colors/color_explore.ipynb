# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from __future__ import division

import numpy as np

from bokeh.layouts import row, column, widgetbox
from bokeh.plotting import  show, output_file, output_notebook

from color_helpers import rgb_from_hex, rgb_to_hsl, \
                          hsl_to_rgb, read_colors, get_colors_dict, JS_HELPERS

from color_explorer import create_init_img, make_layout

# %%
colors_arr = read_colors() 
colors_dict = get_colors_dict( colors_arr )

# %%
N = 100

layout = make_layout( N, colors_dict, colors_arr, widget_size=500)

output_notebook()
#output_file("image_rgba.html", title="image_rgba.py example")

show(layout, browser=None)  # open a browser
#%%
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="5885">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="65378fe2-5773-4d2d-bed1-ed537e8a7afb" data-root-id="5884"></div>

# %%
[c for c in colors_arr if c["name"]== "camouflage green" ]
# Out:
# [{'name': 'camouflage green',
#   'hex': '#4b6113',
#   'r': 75,
#   'g': 97,
#   'b': 19,
#   'h': 21.367521367521366,
#   's': 67.24137931034481,
#   'l': 22.745098039215687}]

# %%
22.74 / 100.0* 255
# Out:
# 57.986999999999995

# %%
from bokeh.models import Dropdown

# %%
help( Dropdown )
# Out:
# Help on class Dropdown in module bokeh.models.widgets.buttons:
#
# class Dropdown(AbstractButton)
#  |  Dropdown(**kwargs)
#  |
#  |  A dropdown button.
#  |
#  |  Method resolution order:
#  |      Dropdown
#  |      AbstractButton
#  |      bokeh.models.widgets.widget.Widget
#  |      bokeh.models.layouts.LayoutDOM
#  |      bokeh.model.Model
#  |      ButtonLike
#  |      bokeh.core.has_props.HasProps
#  |      bokeh.util.callback_manager.PropertyCallbackManager
#  |      bokeh.util.callback_manager.EventCallbackManager
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  js_on_click(self, handler)
#  |      Set up a JavaScript handler for button or menu item clicks.
#  |
#  |  on_click(self, handler)
#  |      Set up a handler for button or menu item clicks.
#  |
#  |      Args:
#  |          handler (func) : handler function to call when button is activated.
#  |
#  |      Returns:
#  |          None
#  |
# ...
